# %%
# Versão da Linguagem Python 
from platform import python_version
python_version()
# Out:
# '3.9.13'

# %% [markdown]
# # Seaborn

# %% [markdown]
# https://seaborn.pydata.org/

# %%
# !pip install -q seaborn==0.12.2

# %%
# Imports
import random
import numpy as np
import pandas as pd
# Seaborn roda acima do matplotlib
import matplotlib as mat
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
np.__version__
# Out:
# '1.26.4'

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
mat.__version__
# Out:
# '3.7.1'

# %%
import seaborn as sea
sea.__version__
# Out:
# '0.12.2'

# %% [markdown]
# # Criando Gráficos

# %%
# Carregando um dos datasets que vem o Seaborn
dados = sea.load_dataset("tips")

# %%
dados.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# O método jointplot cria plot de 2 variáveis com gráficos bivaridos e univariados
sea.jointplot(data = dados, x = "total_bill", y = "tip", kind = "reg")

# %%
# O método lmplot() cria plot com dados e modelos de regressão
sea.lmplot(data = dados, x = "total_bill", y = "tip", col = "smoker")

# %%
# Construindo um dataframe com Pandas
df = pd.DataFrame()

# Alimentando o DataFrame com valores aleatórios
df['idade'] = random.sample(range(20, 100), 30)
df['peso'] = random.sample(range(55, 150), 30)

df.shape
# Out:
# (30, 2)

# %%
df.head()
# Out:
#    idade  peso
# 0     23    89
# 1     62   119
# 2     63    55
# 3     98   128
# 4     61    80

# %%
# lmplot
sea.lmplot(data = df, x = "idade", y = "peso", fit_reg = True)

# %%
# kdeplot
sea.kdeplot(df.idade)
# Out:
# <Axes: xlabel='idade', ylabel='Density'>

# %%
# kdeplot
sea.kdeplot(df.peso)
# Out:
# <Axes: xlabel='peso', ylabel='Density'>

# %%
# distplot 
sea.distplot(df.peso)
# Out:
# <Axes: xlabel='peso', ylabel='Density'>

# %%
# Histograma 
plt.hist(df.idade, alpha = .3)
sea.rugplot(df.idade)
# Out:
# <Axes: xlabel='idade'>

# %%
# Box Plot
sea.boxplot(df.idade, color = "m")
# Out:
# <Axes: >

# %%
# Box Plot
sea.boxplot(df.peso, color = "y")
# Out:
# <Axes: >

# %%
# Violin Plot 
sea.violinplot(df.idade, color = 'g')
# Out:
# <Axes: >

# %%
# Violin Plot 
sea.violinplot(df.peso, color = 'cyan')
# Out:
# <Axes: >

# %%
# Clustermap
sea.clustermap(df)
